# %% [markdown]
# ### Colab Activity 21.3: Using Keras
#
# **Expected Time = 60 minutes**
#
#
#
# This activity focuses on using the `keras` library to build an Artificial Neural Network using the the Titanic dataset.  You will now use all the rows of the data and the `age` and `fare` columns to build a basic network.  After building the model you will visualize the loss for each epoch.
#
# #### Index
#
# - [Problem 1](#-Problem-1)
# - [Problem 2](#-Problem-2)
# - [Problem 3](#-Problem-3)
# - [Problem 4](#-Problem-4)
# - [Problem 5](#-Problem-5)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers, models, optimizers, utils, losses, metrics
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import plot_model

import warnings
warnings.filterwarnings('ignore')

# %%
titanic = sns.load_dataset('titanic').dropna(subset = ['age'])
X = titanic[['age', 'fare']].values
y = titanic['survived'].values
print(X.shape)
# Out:
# (714, 2)

# %% [markdown]
# [Back to top](#-Index)
#
# ### Problem 1
#
# #### A Basic Network
#
#
#
# To begin, use `keras` and the `Sequential` model to create a model with the following architecture:
#
# - One hidden layer with one node
# - One output node
# - Use the sigmoid activation function on all nodes
#
# Assign this model to the variable `single_node_model`.

# %%
tf.random.set_seed(42)
single_node_model = keras.Sequential([
    layers.Dense(1,activation="sigmoid"),
    layers.Dense(1,activation="sigmoid")
    ])

### ANSWER CHECK
single_node_model
# Out:
# <Sequential name=sequential, built=False>

# %%
single_node_model.layers[0].activation
# Out:
# <function keras.src.activations.activations.sigmoid(x)>

# %% [markdown]
# [Back to top](#-Index)
#
# ### Problem 2
#
# #### Compiling the Network
#
#
#
# Now, compile the `single_node_model` model defined above using the settings below:
#
# - `optimizer = rmsprop`
# - `loss = binary_crossentropy`
# - `metrics = ['accuracy']`

# %%
tf.random.set_seed(42)
single_node_model.compile(optimizer = "rmsprop",loss='binary_crossentropy', metrics= ['accuracy'])
### ANSWER CHECK
single_node_model
# Out:
# <Sequential name=sequential, built=False>

# %% [markdown]
# [Back to top](#-Index)
#
# ### Problem 3
#
# #### Fit the model
#
#
#
# Next, fit the `single_node_model` model below to the data `X` and `y` using the following parameters:
#
# - `epochs = 20`
# - `batch_size = 10`
# - `verbose = 0`
#
# Ensure to use `tf.random.set_seed(42)` to assure proper grading.
#
# Assign your fit model to the variable `history` below.

# %%
tf.random.set_seed(42)
history = single_node_model.fit(x=X, y =y, epochs=20, batch_size=10, verbose=0)

### ANSWER CHECK
history.params
# Out:
# {'verbose': 0, 'epochs': 20, 'steps': 72}

# %% [markdown]
# [Back to top](#-Index)
#
# ### Problem 4
#
# #### Evaluate the model
#
#
#
# Use the `.evaluate` method on your `single_node_model` with the `X` and `y` arrays to examine the loss and accuracy of the model.  Assign these values to the variables `single_loss` and `single_acc` below.

# %%
single_loss = ''
single_acc = ''
loss_acc=single_node_model.evaluate(X,y)
single_loss= loss_acc[0]
single_acc = loss_acc[1]


### ANSWER CHECK
print(single_loss)
print(single_acc)
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5938 - loss: 0.6769
# 0.6768581867218018
# 0.593837559223175

# %%
single_loss = ''
single_acc = ''



### ANSWER CHECK
print(single_loss)
print(single_acc)
# Out:
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6755 - accuracy: 0.5938
# 0.6754795908927917
# 0.593837559223175

# %% [markdown]
# [Back to top](#-Index)
#
# ### Problem 5
#
# #### A More Complex Model
#
#
#
# To try to improve the model, now build and evaluate a second model that uses a single hidden layer with 100 nodes, and a single output layer.
#
# For the hidden layer use the `relu` activation function and for the output layer use the `sigmoid` activation.
#
# Again, set the `np.random.seed(42)`, using the same compile settings and train settings for number of epochs and batch size.  Assign the accuracy of the model to `hundred_acc` below.

# %%
np.random.seed(42)
complex_model = keras.Sequential([
    layers.Dense(100,activation='relu'),
    layers.Dense(1,activation='sigmoid')
])

complex_model.compile(optimizer = "rmsprop",loss='binary_crossentropy', metrics= ['accuracy'])
history_complex = complex_model.fit(x=X, y = y , epochs=20, batch_size=10, verbose=1)
hundred_acc=complex_model.evaluate(X,y)


### ANSWER CHECK
print(hundred_acc)
# Out:
# Epoch 1/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6373 - loss: 1.1756
# Epoch 2/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6569 - loss: 0.6523
# Epoch 3/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6611 - loss: 0.6518
# Epoch 4/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6611 - loss: 0.6504
# Epoch 5/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6597 - loss: 0.6496
# Epoch 6/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6611 - loss: 0.6489
# Epoch 7/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6611 - loss: 0.6481
# Epoch 8/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6653 - loss: 0.6475
# Epoch 9/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6653 - loss: 0.6468
# Epoch 10/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6625 - loss: 0.6464
# Epoch 11/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6625 - loss: 0.6459
# Epoch 12/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6639 - loss: 0.6452
# Epoch 13/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6625 - loss: 0.6449
# Epoch 14/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6611 - loss: 0.6449
# Epoch 15/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6611 - loss: 0.6442
# Epoch 16/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6625 - loss: 0.6438
# Epoch 17/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6625 - loss: 0.6436
# Epoch 18/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6625 - loss: 0.6429
# Epoch 19/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6625 - loss: 0.6423
# Epoch 20/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6625 - loss: 0.6417
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6821 - loss: 0.6234
# [0.6233886480331421, 0.6820728182792664]
